# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import RegressorMixin, TransformerMixin
from sklearn.preprocessing import PowerTransformer, QuantileTransformer, StandardScaler
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, LinearRegression, ElasticNet, ElasticNetCV

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import cross_validate, KFold
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import TimeSeriesSplit

# %%
# Import custom classes
from supervised_model_pipeline import EdaToolbox, RegressorMultiModelEvaluator

# %% [markdown]
# ## Inspect the data

# %%
# Load the training data
denver_file_path = '../Data/Clean/combined/Denver_combined.csv'
train_full_df = pd.read_csv(denver_file_path)
train_full_df.head()
# Out:
#          DATE  MeanSalePrice  SalesCount  TotalTransactionValue  \
# 0  2008-04-30       245069.0      4305.0           9.275848e+08
# 1  2008-05-31       242919.0      4779.0           1.043794e+09
# 2  2008-06-30       245529.0      4789.0           1.136320e+09
# 3  2008-07-31       247607.0      4922.0           1.195890e+09
# 4  2008-08-31       246384.0      4333.0           1.154412e+09
#
#    HomeValueIndex  HomeValueIndexSmSa  MarketTempIdx  DaysToClose  \
# 0   239786.727396       243635.279120            NaN          NaN
# 1   240755.620219       242719.130794            NaN          NaN
# 2   241296.223700       241952.165191            NaN          NaN
# 3   240843.494803       240801.464621            NaN          NaN
# 4   239424.931087       239672.270501            NaN          NaN
#
#    DaysOnZillow  ListingPriceCutAmt  ...  PctSoldBelowList  MORTGAGE15US  \
# 0           NaN                 NaN  ...               NaN         5.465
# 1           NaN                 NaN  ...               NaN         5.600
# 2           NaN                 NaN  ...               NaN         5.910
# 3           NaN                 NaN  ...               NaN         5.972
# 4           NaN                 NaN  ...               NaN         6.025
#
#    MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.918            0.452    1259.0         1.0
# 1         6.036            0.436    1256.8        -1.0
# 2         6.320            0.410    1258.2        -0.6
# 3         6.426            0.454    1256.1        -1.0
# 4         6.478            0.452    1256.2        -0.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                   2434.5429                  91.688128
# 1                   2434.5429                  91.688128
# 2                   2434.5429                  91.688128
# 3                   2434.5429                  91.688128
# 4                   2434.5429                  91.688128
#
#    PctBachelorsDegree_2019    CityName
# 0                49.747029  DENVER, CO
# 1                49.747029  DENVER, CO
# 2                49.747029  DENVER, CO
# 3                49.747029  DENVER, CO
# 4                49.747029  DENVER, CO
#
# [5 rows x 26 columns]

# %%
# Remove columns that are too predictive
cols_to_remove = ['HomeValueIndexSmSa', 'HomeValueIndex']
train_full_df = train_full_df.drop(cols_to_remove, axis=1)

# %% [markdown]
# ## Create an EdaToolbox object

# %%
# Initialize the EdaToolbox
target_col = 'MeanSalePrice'
eda = EdaToolbox(train_full_df, target_column=target_col)

# %%
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#                            data_type  max_value_count_pct most_frequent_value  \
# CityName                      object             1.000000          DENVER, CO
# DATE                          object             0.005128          2008-04-30
# People25PlusThousands_2019   float64             1.000000           2434.5429
# PctHighSchoolDiploma_2019    float64             1.000000           91.688128
# PctBachelorsDegree_2019      float64             1.000000           49.747029
#
#                             unique_values  missing_values  missing_values_pct  \
# CityName                                1               0                 0.0
# DATE                                  195               0                 0.0
# People25PlusThousands_2019              1               0                 0.0
# PctHighSchoolDiploma_2019               1               0                 0.0
# PctBachelorsDegree_2019                 1               0                 0.0
#
#                                                                 top_10_values
# CityName                    Index(['DENVER, CO'], dtype='object', name='Ci...
# DATE                        Index(['2008-04-30', '2012-05-31', '2009-03-31...
# People25PlusThousands_2019  Index([2434.5429], dtype='float64', name='Peop...
# PctHighSchoolDiploma_2019   Index([91.688128], dtype='float64', name='PctH...
# PctBachelorsDegree_2019     Index([49.747029], dtype='float64', name='PctB...

# %%
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# %% [markdown]
# ## First check the distribution of the target column and select an appropriate target column transformer

# %%
# It is not normally distributed. It has a long tail to the right. Need to try different target transformations
target_transformation_dict: dict[str, TransformerMixin] = {
    'StandardScaler': StandardScaler(),
    'PowerTransformer': PowerTransformer(standardize=False),
    'QuantileTransformer': QuantileTransformer(output_distribution='normal', n_quantiles=500, random_state=42),
}

# %%
# Create a dict of models for preliminary testing of target transformations
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'Lasso Regression': Lasso(alpha=1.0, random_state=42),
    'ElasticNet Regression': ElasticNet(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(np.logspace(-6, 6, 25)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
kf_cv = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Use basic ordinal feature transformer
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015986157496120867, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021181802677047834, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021905937830480227, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021590484701232704, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021016984056318577, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020364738534873084, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01968110789841404, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0162214815095707, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02019036796628626, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03171165516704377, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027600086575205296, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03284887476477394, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03357255197563802, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03316465073014996, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.032457023647836536, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03165413337180212, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016892696883699543, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018600628504485073, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027393913427950167, tolerance: 0.01941728604064221
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028915346055530478, tolerance: 0.01941728604064221
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028693548792340096, tolerance: 0.01941728604064221
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027355068792406456, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.014339410295264088, tolerance: 0.009130961036912109
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02864118935447202, tolerance: 0.016059567587093766
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03237654877165319, tolerance: 0.016059567587093766
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0272611543418968, tolerance: 0.017176190174603517
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02652861042755461, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027852976837213106, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02715572126744803, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026451397066132643, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02574950329272241, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024379157980227717, tolerance: 0.02018457433134315
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027963217147792818, tolerance: 0.02018457433134315
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02823287839975208, tolerance: 0.02018457433134315
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027684058058422778, tolerance: 0.02018457433134315
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.102294          0.101943          1.001399
# PowerTransformer              0.000144          0.000160          0.002421
# QuantileTransformer           0.360410          0.346947          1.063085
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.659355  0.106030      0.099204  0.101047
# PowerTransformer                  0.002421  0.000152      0.000152  0.000144
# QuantileTransformer               0.728569  0.330695      0.330933  0.349981
#
#                      HistGradientBoost
# StandardScaler                0.046733
# PowerTransformer              0.000110
# QuantileTransformer           0.306000

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020508627865137186, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024420267435829146, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02448601866276512, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023819497288354086, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02300907824624332, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022147078123033737, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021034516416547966, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025935894988174724, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026666865460832412, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02623803396103419, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01767227283264816, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02631267967242934, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027756045161112297, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02752165028496023, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04230050275704045, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02647621295605518, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021657529205501902, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020397570050384672, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019697115801729836, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019080361372161292, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019252851211327027, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026897579205570565, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028241998954086966, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028047438065684105, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02747219421434366, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02678682690581624, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02606068363664349, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02531713365143773, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.102488          0.098333          0.987266
# PowerTransformer              0.000152          0.000161          0.002355
# QuantileTransformer           0.312930          0.252940          1.003459
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.653573  0.103120      0.099920  0.099681
# PowerTransformer                  0.002355  0.000157      0.000157  0.000151
# QuantileTransformer               0.663008  0.167532      0.173911  0.239239
#
#                      HistGradientBoost
# StandardScaler                0.039813
# PowerTransformer              0.000101
# QuantileTransformer           0.212164

# %%
# Use basic OHE feature transformer
eda.feature_transformer = eda.get_basic_ohe_feature_transformer()

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022405872384300807, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026294628429472056, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021321171992532584, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019078013092336477, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018276013148057046, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017692481913892166, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022449203802731077, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02411009100423378, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023903726566128825, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03663392828874734, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030302586586060443, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027134206983120635, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025911410445548455, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024993340862437208, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02412753080232477, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03439434108558714, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.037407518685157015, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.037225506766546346, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02193290111910784, tolerance: 0.01815652567742971
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03424302732757667, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.034904483622892, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02129553827014874, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028830637890109756, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03071741378911952, tolerance: 0.019514805279635457
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021321758330621776, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024388683305193837, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024891909931515244, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022468015719805834, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02101284868758313, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020319550256973073, tolerance: 0.009432712865027771
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03245426305522514, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03504956938651915, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.034993782891177716, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03426998080319521, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028443157836406385, tolerance: 0.009130961036912109
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03621538004142266, tolerance: 0.009130961036912109
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025011242910755627, tolerance: 0.01613191491598543
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03640062135229982, tolerance: 0.01613191491598543
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.039247588376223774, tolerance: 0.01613191491598543
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02269639703965254, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026971012512859716, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02738599950957621, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02690467620947956, tolerance: 0.01873887376747389
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.212704          0.212297          1.001399
# PowerTransformer              0.000490          0.000488          0.002421
# QuantileTransformer           0.451849          0.442372          1.095851
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.726922  0.349667      0.378371  0.215122
# PowerTransformer                  0.002421  0.000683      0.000683  0.000501
# QuantileTransformer               0.803178  0.543734      0.548439  0.448152
#
#                      HistGradientBoost
# StandardScaler                0.115293
# PowerTransformer              0.000380
# QuantileTransformer           0.338063

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022374966462081147, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02260133167877143, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021097454491574297, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019458626129299716, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018656308629857676, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017976500189732292, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017324109146024114, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025672483961628245, tolerance: 0.017116948405645115
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02116591034399562, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02325841570282705, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025645320954261308, tolerance: 0.013798912281812157
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.050727292484634035, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06317756327177193, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04503164699362827, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024721705378457415, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021125644213569217, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01994624549187307, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01916759629098408, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018470095644403273, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.037802277932833306, tolerance: 0.017315139296859468
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02949689171294878, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.031749890583288476, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03148812924077404, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029050602364623757, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020148323034369753, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018309807105652, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017484971938827698, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016826168591599355, tolerance: 0.016549203700666197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# c:\Users\jim\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2762: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.200035          0.195907          0.987266
# PowerTransformer              0.000472          0.000477          0.002355
# QuantileTransformer           0.411798          0.371610          1.041754
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.719048  0.196792      0.196583  0.199607
# PowerTransformer                  0.002355  0.000479      0.000479  0.000477
# QuantileTransformer               0.734977  0.336833      0.336310  0.371610
#
#                      HistGradientBoost
# StandardScaler                0.064513
# PowerTransformer              0.000456
# QuantileTransformer           0.270631

# %% [markdown]
# ## Set the target and feature column tranformers
#
# * Use the PowerTransformer for the target column
# * Use the basic ordinal feature transformer

# %%
# Looks like the CV Models perform the best with a PowerTransformer.
# NOTE: These are pretty good RMSE scores with very basic encoding and no feature selection
eda.target_transformer = PowerTransformer(standardize=False)
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %% [markdown]
# ## Prepare the data for feature selection

# %%
# Gather initial column information sorted by data type and max value count to check for columns with high cardinality that can be pruned
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#                            data_type  max_value_count_pct most_frequent_value  \
# CityName                      object             1.000000          DENVER, CO
# DATE                          object             0.005128          2008-04-30
# People25PlusThousands_2019   float64             1.000000           2434.5429
# PctHighSchoolDiploma_2019    float64             1.000000           91.688128
# PctBachelorsDegree_2019      float64             1.000000           49.747029
#
#                             unique_values  missing_values  missing_values_pct  \
# CityName                                1               0                 0.0
# DATE                                  195               0                 0.0
# People25PlusThousands_2019              1               0                 0.0
# PctHighSchoolDiploma_2019               1               0                 0.0
# PctBachelorsDegree_2019                 1               0                 0.0
#
#                                                                 top_10_values
# CityName                    Index(['DENVER, CO'], dtype='object', name='Ci...
# DATE                        Index(['2008-04-30', '2012-05-31', '2009-03-31...
# People25PlusThousands_2019  Index([2434.5429], dtype='float64', name='Peop...
# PctHighSchoolDiploma_2019   Index([91.688128], dtype='float64', name='PctH...
# PctBachelorsDegree_2019     Index([49.747029], dtype='float64', name='PctB...

# %%
# Set pruning thresholds on the eda object according to column data type and cardinality for this dataset
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# %% [markdown]
# ## Feature analysis

# %%
# Frist check what the correlation and coefficient numbers look like
fa_df = eda.get_regression_feature_analysis_df()
fa_df.head()
# Out:
# Best RidgeCV alpha: 0.01 (R^2 score:  1.00)
# c:\Users\jim\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\jim\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# c:\Users\jim\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                                       correlation_abs  coefficient_abs  \
# ordinal_date__DATE                           0.996436         0.002019
# numerical__NUM_JOBS                          0.954660         0.000171
# numerical__TotalTransactionValue             0.838063         0.000287
# numerical__NewConstructMeanSalePrice         0.244011         0.000002
# numerical__DaysToClose                       0.206733         0.000002
#
#                                           pval        vif  PCA1_abs  PCA2_abs  \
# ordinal_date__DATE                    0.429273  26.018112  0.092671  0.176204
# numerical__NUM_JOBS                   0.982616  15.817053  0.053392  0.195729
# numerical__TotalTransactionValue      0.866099  29.194217  0.182542  0.039204
# numerical__NewConstructMeanSalePrice  0.905697   6.106051  0.127860  0.425397
# numerical__DaysToClose                0.985549   6.079443  0.204036  0.350230
#
#                                          total
# ordinal_date__DATE                    1.267330
# numerical__NUM_JOBS                   1.203953
# numerical__TotalTransactionValue      1.060097
# numerical__NewConstructMeanSalePrice  0.797270
# numerical__DaysToClose                0.761002

# %%
# Plot out the highly correlated features
eda.plot_regression_feature_correlations(corr_min=0.2)
# Out:
# c:\Users\jim\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\jim\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# ## Perform unsupervised feature selection

# %%
# Try recursive feature elimination to find the optimal number of features for a linear regression model
regressor = LinearRegression()
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
rfecv_results_df.head()
# Out:
# Optimal number of features: 11
#    mean_test_score  std_test_score  split0_test_score  split1_test_score  \
# 0    -1.446627e-05    1.919817e-05      -2.423091e-05      -6.008279e-08
# 1    -1.895393e-05    2.364710e-05      -3.983595e-05      -5.622215e-08
# 2    -1.915831e-05    2.394571e-05      -3.957218e-05      -8.348154e-08
# 3    -1.208198e-07    8.171272e-08      -2.742788e-07      -8.367302e-08
# 4    -1.215408e-07    1.028688e-07      -3.215172e-07      -5.926304e-08
#
#    split2_test_score  split3_test_score  split4_test_score  selected  ranking  \
# 0      -2.567713e-08      -3.478394e-08      -4.797990e-05     False        3
# 1      -2.579526e-08      -3.127013e-08      -5.482040e-05      True        1
# 2      -2.564509e-08      -1.083286e-07      -5.600191e-05     False        7
# 3      -3.078733e-08      -1.091197e-07      -1.062400e-07     False        8
# 4      -3.306086e-08      -9.759201e-08      -9.627104e-08      True        1
#
#             feature_name
# 0             SalesCount
# 1  TotalTransactionValue
# 2          MarketTempIdx
# 3            DaysToClose
# 4           DaysOnZillow

# %%
rfe_lr_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE LR Selected Features: {rfe_lr_selected_features}")
# Out:
# RFE LR Selected Features: ['TotalTransactionValue' 'DaysOnZillow' 'ListingPriceCutPct'
#  'PctListingsPriceCut' 'PctSoldAboveList' 'PctSoldBelowList'
#  'MORTGAGE15US' 'MORTGAGE30US' 'RATE_DIFFERENCE' 'NUM_JOBS' 'DATE']

# %%
# Try recursive feature elimination to find the optimal number of features for a RidgeCV model
regressor = RidgeCV(alphas=np.logspace(-6, 6, num=5))
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
# Out:
# Optimal number of features: 10

# %%
rfe_ridge_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE Ridge Selected features: {rfe_ridge_selected_features}")
# Out:
# RFE Ridge Selected features: ['TotalTransactionValue' 'DaysOnZillow' 'ListingPriceCutPct'
#  'PctListingsPriceCut' 'PctSoldAboveList' 'PctSoldBelowList'
#  'MORTGAGE15US' 'MORTGAGE30US' 'NUM_JOBS' 'DATE']

# %%
# Try using forward SFS (SequentialFeatureSelector) to select the top 28 features
sfs_ridge_selected_features = eda.perform_unsupervised_regression_sfs_feature_selection(n_features=10)
print(f"SFS Ridge Selected Features: {sfs_ridge_selected_features}")
# Out:
# RidgeCV best alpha 0.001
# Selected 10 features by forward sequential featureselection in 3.465 seconds
# SFS Ridge Selected Features: ['SalesCount', 'DaysOnZillow', 'ListingPriceCutPct', 'NewConstructSalesCount', 'PctSoldBelowList', 'RATE_DIFFERENCE', 'NUM_JOBS', 'GROWTH_PCT', 'DATE', 'CityName']

# %%
# Remove colinear features from the list of selected features
# rfe_ridge_selected_features = [rfe_ridge_selected_features]
rfe_ridge_selected_features = list(rfe_ridge_selected_features)
rfe_ridge_selected_features.remove('PctSoldAboveList')
rfe_ridge_selected_features.remove('MORTGAGE15US')
rfe_ridge_selected_features
# Out:
# ['TotalTransactionValue',
#  'DaysOnZillow',
#  'ListingPriceCutPct',
#  'PctListingsPriceCut',
#  'PctSoldBelowList',
#  'MORTGAGE30US',
#  'NUM_JOBS',
#  'DATE']

# %%
# Update EDA object with selected features from RFE
eda.selected_feature_list = rfe_ridge_selected_features

# Now get the list of selected ordinal columns
final_ordinal_cols = eda.get_final_ordinal_col_names(rfe_lr_selected_features)
len(final_ordinal_cols), final_ordinal_cols
# Out:
# (1, ['DATE'])

# %% [markdown]
# ## Perform final EDA with selected features and ordinal columns

# %%
# Reset transformer properties to use the selected columns and ordinal columns
eda.ordinal_encoding_col_dict = {}
for col_name in final_ordinal_cols:
    eda.add_ordinal_encoding_column(col_name, None)

eda.feature_transformer = eda.create_feature_transformer()
eda.feature_transformer
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(memory='named_steps',
#                                           steps=[('pruner',
#                                                   SimplePruner(infreq=0.95,
#                                                                pct_miss=0.8)),
#                                                  ('selector',
#                                                   SelectedFeaturesTransformer(selected_feature_list=['TotalTransactionValue',
#                                                                                                      'DaysOnZillow',
#                                                                                                      'ListingPriceCutPct',
#                                                                                                      'PctListingsPriceCut',
#                                                                                                      'PctSoldBelowList',
#                                                                                                      'MORTGAGE30US',
#                                                                                                      'NUM_JOBS',
#                                                                                                      'DATE'])),
#                                                  ('imputer', SimpleI...
#                                                                               '2010-01-31',
#                                                                               '2008-09-30',
#                                                                               '2010-03-31',
#                                                                               '2011-03-31',
#                                                                               '2010-02-28',
#                                                                               '2010-04-30',
#                                                                               '2009-09-30',
#                                                                               '2008-05-31',
#                                                                               '2011-04-30',
#                                                                               '2009-07-31',
#                                                                               '2011-02-28',
#                                                                               '2008-04-30',
#                                                                               '2010-05-31',
#                                                                               '2008-06-30',
#                                                                               '2009-08-31',
#                                                                               '2008-08-31',
#                                                                               '2008-07-31',
#                                                                               '2011-05-31', ...]],
#                                                                  encoded_missing_value=-2,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['DATE'])])

# %%
# Check feature analysis to ensure we have no multicollinearity (ie. no infinite vifs)
feature_analysis_df = eda.get_regression_feature_analysis_df()
feature_analysis_df.head()
# Out:
# Best RidgeCV alpha: 1e-06 (R^2 score:  1.00)
#                                   correlation_abs  coefficient_abs      pval  \
# ordinal_date__DATE                       0.996436         0.002090  0.210123
# numerical__NUM_JOBS                      0.954660         0.000157  0.954832
# numerical__TotalTransactionValue         0.838063         0.000195  0.950792
# numerical__PctSoldBelowList              0.095451         0.000122  0.908569
# numerical__DaysOnZillow                  0.072127         0.000048  0.892728
#
#                                         vif  PCA1_abs  PCA2_abs     total
# ordinal_date__DATE                14.474358  0.256018  0.534230  1.788774
# numerical__NUM_JOBS               13.068360  0.201056  0.563570  1.719444
# numerical__TotalTransactionValue   8.382517  0.383366  0.388607  1.610232
# numerical__PctSoldBelowList       31.325212  0.484682  0.233860  0.814116
# numerical__DaysOnZillow           16.745793  0.456604  0.211226  0.740005

# %%
eda.plot_important_features(feature_analysis_df)

# %% [markdown]
# # Now do model analysis for multiple regression models

# %%
# Reload the data just to be safe
train_full_df = pd.read_csv(denver_file_path)

# Create an instance of RegressorMultiModelEvaluator and set various properties
reg = RegressorMultiModelEvaluator(train_full_df, target_column=target_col)
reg.set_column_transformer_properties(selected_feature_list=eda.selected_feature_list, ordinal_feature_list=final_ordinal_cols)
reg.set_target_column_transformer(eda.target_transformer)

# %%
# Create a dict of models to test
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(alphas=np.logspace(-6, 6, num=7)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
# Evaluate the models
eval_df = reg.evaluate_models(model_dict)
eval_df
# Out:
# Number original X cols: 25
# Number scaled X cols: 8
#                    train_r2           mse        r2    r2_adj  lr_cv_mean  \
# model_name
# HistGradientBoost  0.998410  2.250741e-08  0.995916  0.994827    0.991069
# Ridge Regression   0.995909  3.124226e-08  0.994331  0.992819    0.991069
# Linear Regression  0.996193  3.243271e-08  0.994115  0.992545    0.991069
# RidgeCV            0.996193  3.243278e-08  0.994115  0.992545    0.991069
# ElasticNetCV       0.996151  3.330167e-08  0.993957  0.992345    0.991069
# LassoCV            0.996151  3.330299e-08  0.993957  0.992345    0.991069
#
#                    lr_cv_std      time  \
# model_name
# HistGradientBoost   0.004267  0.397030
# Ridge Regression    0.004267  0.022034
# Linear Regression   0.004267  0.061150
# RidgeCV             0.004267  0.024262
# ElasticNetCV        0.004267  0.155947
# LassoCV             0.004267  0.166760
#
#                                                               y_pred
# model_name
# HistGradientBoost  [2.552913162429354, 2.548636707618142, 2.55382...
# Ridge Regression   [2.552927454239785, 2.5485254556003376, 2.5540...
# Linear Regression  [2.5528824087759188, 2.548531198687603, 2.5540...
# RidgeCV            [2.5528824089236903, 2.5485311978396044, 2.554...
# ElasticNetCV       [2.552903638375998, 2.548521290862036, 2.55408...
# LassoCV            [2.552903620547811, 2.5485212929854857, 2.5540...

# %%
reg.plot_model_evaluations()

# %%
# Get the best model
reg.best_model_name
# Out:
# 'HistGradientBoost'

# %% [markdown]
# ## Now use the best model to predict on the test data

# %%
# Load test data from a different city
atlanta_file_path = '../../Data/Clean/combined/Atlanta_combined.csv'
test_full_df = pd.read_csv(atlanta_file_path)
test_full_df.head()
# Out:
#          DATE  MeanSalePrice  SalesCount  TotalTransactionValue  \
# 0  2008-04-30       200954.0      6463.0           1.235943e+09
# 1  2008-05-31       203419.0      6729.0           1.317605e+09
# 2  2008-06-30       205746.0      7047.0           1.388670e+09
# 3  2008-07-31       205553.0      7086.0           1.429205e+09
# 4  2008-08-31       202855.0      6383.0           1.388101e+09
#
#    HomeValueIndex  HomeValueIndexSmSa  MarketTempIdx  DaysToClose  \
# 0   185168.707578       189442.061550            NaN          NaN
# 1   185331.245765       188426.220342            NaN          NaN
# 2   185185.095114       187437.288971            NaN          NaN
# 3   184692.089305       186253.861325            NaN          NaN
# 4   183376.364934       184882.815462            NaN          NaN
#
#    DaysOnZillow  ListingPriceCutAmt  ...  PctSoldBelowList  MORTGAGE15US  \
# 0           NaN                 NaN  ...               NaN         5.465
# 1           NaN                 NaN  ...               NaN         5.600
# 2           NaN                 NaN  ...               NaN         5.910
# 3           NaN                 NaN  ...               NaN         5.972
# 4           NaN                 NaN  ...               NaN         6.025
#
#    MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.918            0.452    2454.9        -3.5
# 1         6.036            0.436    2450.9        -6.2
# 2         6.320            0.410    2442.4        -6.1
# 3         6.426            0.454    2434.6        -6.8
# 4         6.478            0.452    2429.3        -7.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                  4414.04779                  89.810682
# 1                  4414.04779                  89.810682
# 2                  4414.04779                  89.810682
# 3                  4414.04779                  89.810682
# 4                  4414.04779                  89.810682
#
#    PctBachelorsDegree_2019     CityName
# 0                41.859123  ATLANTA, GA
# 1                41.859123  ATLANTA, GA
# 2                41.859123  ATLANTA, GA
# 3                41.859123  ATLANTA, GA
# 4                41.859123  ATLANTA, GA
#
# [5 rows x 26 columns]

# %%
# Drop target column
atlanta_actual_values = test_full_df[target_col]
test_full_df = test_full_df.drop(columns=[target_col])
test_full_df.head()
# Out:
#          DATE  SalesCount  TotalTransactionValue  HomeValueIndex  \
# 0  2008-04-30      6463.0           1.235943e+09   185168.707578
# 1  2008-05-31      6729.0           1.317605e+09   185331.245765
# 2  2008-06-30      7047.0           1.388670e+09   185185.095114
# 3  2008-07-31      7086.0           1.429205e+09   184692.089305
# 4  2008-08-31      6383.0           1.388101e+09   183376.364934
#
#    HomeValueIndexSmSa  MarketTempIdx  DaysToClose  DaysOnZillow  \
# 0       189442.061550            NaN          NaN           NaN
# 1       188426.220342            NaN          NaN           NaN
# 2       187437.288971            NaN          NaN           NaN
# 3       186253.861325            NaN          NaN           NaN
# 4       184882.815462            NaN          NaN           NaN
#
#    ListingPriceCutAmt  ListingPriceCutPct  ...  PctSoldBelowList  \
# 0                 NaN                 NaN  ...               NaN
# 1                 NaN                 NaN  ...               NaN
# 2                 NaN                 NaN  ...               NaN
# 3                 NaN                 NaN  ...               NaN
# 4                 NaN                 NaN  ...               NaN
#
#    MORTGAGE15US  MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.465         5.918            0.452    2454.9        -3.5
# 1         5.600         6.036            0.436    2450.9        -6.2
# 2         5.910         6.320            0.410    2442.4        -6.1
# 3         5.972         6.426            0.454    2434.6        -6.8
# 4         6.025         6.478            0.452    2429.3        -7.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                  4414.04779                  89.810682
# 1                  4414.04779                  89.810682
# 2                  4414.04779                  89.810682
# 3                  4414.04779                  89.810682
# 4                  4414.04779                  89.810682
#
#    PctBachelorsDegree_2019     CityName
# 0                41.859123  ATLANTA, GA
# 1                41.859123  ATLANTA, GA
# 2                41.859123  ATLANTA, GA
# 3                41.859123  ATLANTA, GA
# 4                41.859123  ATLANTA, GA
#
# [5 rows x 25 columns]

# %%
# Make predictions with HistGradientBoost
#reg.best_model = model_dict['Linear Regression']
lr_predictions = reg.predict(test_full_df)
lr_predictions
# Out:
# array([241506.47376453, 241506.47376453, 246831.23931787, 249677.72837531,
#        248973.26976424, 241506.47376453, 238514.80505304, 237812.72731747,
#        228260.63067792, 224329.98603346, 223980.98766433, 224153.14095868,
#        232591.02029102, 240628.88855714, 240677.82349467, 240677.82349467,
#        248809.57865371, 240868.06314062, 245177.45698066, 245646.00230203,
#        245699.64539673, 227840.77710976, 236210.51454422, 236210.51454422,
#        238988.28548727, 245123.97219938, 256211.89854849, 263395.78317392,
#        268236.5141149 , 266627.47693257, 268843.29859498, 261736.48395541,
#        256056.40343792, 249308.94207604, 234106.4488921 , 234438.31430285,
#        234438.31430285, 247316.82131243, 253119.49508437, 257603.22729375,
#        257425.61317096, 254005.50473545, 250248.30916645, 250415.44725698,
#        251798.06121682, 250759.46285839, 252045.76773256, 255634.1365276 ,
#        259901.85521972, 270147.9099866 , 280130.05383014, 286199.85959606,
#        286857.98324111, 284164.07356708, 279243.0525873 , 280639.04528408,
#        280639.04528408, 275164.10993031, 275174.14694617, 280745.95388631,
#        287694.30359107, 297625.17513252, 306829.6832363 , 310812.11590344,
#        309259.76668181, 303412.93957221, 298231.94078013, 293912.48919435,
#        292085.4222774 , 295849.61192196, 293032.63521631, 293929.77087267,
#        300075.48699187, 311292.6300456 , 322036.48932117, 321878.29796763,
#        319232.27317416, 312575.23893905, 309697.55772894, 310994.3993395 ,
#        317275.32947452, 320117.88339066, 326638.93328539, 326638.93328539,
#        336357.46698227, 344861.97430184, 352098.47863269, 353174.20889106,
#        349887.41533375, 344686.95563639, 345056.7556587 , 345778.42983114,
#        349928.04474907, 352220.54458609, 352989.87494565, 360219.93107108,
#        360262.20732734, 377647.95122261, 386887.36082691, 392348.52056265,
#        391967.71980565, 384653.24886906, 382381.78046237, 383766.31620013,
#        385055.32664385, 383837.67792792, 384667.71806015, 392394.17723398,
#        406392.19195152, 417731.81063193, 429304.73382476, 428967.9507543 ,
#        423777.11675787, 406055.12722193, 417540.38237038, 424089.24820814,
#        424079.13630364, 430045.30179059, 431291.46589737, 432933.71177693,
#        451645.47422464, 459692.08805505, 470858.12510613, 463962.35537245,
#        462059.23348573, 454077.72374022, 444892.89523387, 451647.48965562,
#        438869.37439015, 437133.10920008, 434074.90375646, 441223.53975612,
#        456232.02321849, 465469.38464488, 475866.26457946, 476201.18225877,
#        470197.68564683, 460615.87389906, 456048.5503392 , 460121.63204559,
#        456388.44488328, 455500.36819123, 455349.43331181, 471396.55613508,
#        478443.0088319 , 482650.71392674, 481290.55372647, 490377.47842041,
#        514789.38508929, 515440.61762434, 530272.85319861, 527718.2395081 ,
#        527836.22532662, 523541.68746416, 526216.24572087, 529334.91581787,
#        575605.28953681, 596032.17858227, 612983.28901343, 614860.94596258,
#        614860.94596258, 613412.24009324, 604508.54288213, 609541.75633789,
#        609541.75633789, 615537.76205192, 618379.64863619, 671250.74521642,
#        703183.5039904 , 696038.40952077, 696038.40952077, 696038.40952077,
#        696038.40952077, 684888.31405203, 684580.10362874, 662274.68198854,
#        656930.92640633, 619912.19020564, 619683.30153951, 654050.13804817,
#        665308.11727849, 679659.86226007, 684888.31405203, 684888.31405203,
#        684888.31405203, 680925.31441818, 671354.0474072 , 663697.74306407,
#        660317.78584234, 628939.38799239, 630294.82067049, 655379.84345925,
#        667131.02645759, 679197.00925204, 679197.00925204])

# %%
# Plot Actual vs Predictions
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Atlanta Predictions vs Actuals")
ax.plot(
    atlanta_actual_values,
    "x-",
    alpha=0.2,
    label=f"Actual {target_col} values",
    color="black",
)
ax.plot(lr_predictions, "x-", label="HistGradientBoost")
_ = ax.legend()
