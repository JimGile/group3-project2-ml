# %% [markdown]
# # Set up

# %%
import pandas as pd

# %%
sale_price_city = pd.read_csv('../data/Sale_Prices_City.csv')

# %%
sale_price_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3728 entries, 0 to 3727
# Columns: 150 entries, Unnamed: 0 to 2020-03
# dtypes: float64(132), int64(16), object(2)
# memory usage: 4.3+ MB

# %%
sale_price_city.value_counts()
# Out:
# Unnamed: 0  RegionID  RegionName     StateName       SizeRank  2008-03   2008-04   2008-05   2008-06   2008-07   2008-08   2008-09   2008-10   2008-11   2008-12   2009-01   2009-02   2009-03   2009-04   2009-05   2009-06   2009-07   2009-08   2009-09   2009-10   2009-11   2009-12   2010-01   2010-02   2010-03   2010-04   2010-05   2010-06   2010-07   2010-08   2010-09   2010-10   2010-11   2010-12   2011-01   2011-02   2011-03   2011-04   2011-05   2011-06   2011-07   2011-08   2011-09   2011-10   2011-11   2011-12   2012-01   2012-02   2012-03   2012-04   2012-05   2012-06   2012-07   2012-08   2012-09   2012-10   2012-11   2012-12   2013-01   2013-02   2013-03   2013-04   2013-05   2013-06   2013-07   2013-08   2013-09   2013-10   2013-11   2013-12   2014-01   2014-02   2014-03   2014-04   2014-05   2014-06   2014-07   2014-08   2014-09   2014-10   2014-11   2014-12   2015-01   2015-02   2015-03   2015-04   2015-05   2015-06   2015-07   2015-08   2015-09   2015-10   2015-11   2015-
# ...

# %%
sale_price_city.columns
# Out:
# Index(['Unnamed: 0', 'RegionID', 'RegionName', 'StateName', 'SizeRank',
#        '2008-03', '2008-04', '2008-05', '2008-06', '2008-07',
#        ...
#        '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11',
#        '2019-12', '2020-01', '2020-02', '2020-03'],
#       dtype='object', length=150)

# %%
columns_to_drop = sale_price_city.filter(regex='^(200[8-9]|201[0-7]|2018-01)').columns
sale_price_city = sale_price_city.drop(columns=columns_to_drop, axis=1)

sale_price_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3728 entries, 0 to 3727
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3728 non-null   int64
#  1   RegionID    3728 non-null   int64
#  2   RegionName  3728 non-null   object
#  3   StateName   3728 non-null   object
#  4   SizeRank    3728 non-null   int64
#  5   2018-02     3712 non-null   float64
#  6   2018-03     3728 non-null   int64
#  7   2018-04     3728 non-null   int64
#  8   2018-05     3728 non-null   int64
#  9   2018-06     3728 non-null   int64
#  10  2018-07     3728 non-null   int64
#  11  2018-08     3728 non-null   int64
#  12  2018-09     3728 non-null   int64
#  13  2018-10     3728 non-null   int64
#  14  2018-11     3728 non-null   int64
#  15  2018-12     3728 non-null   int64
#  16  2019-01     3728 non-null   int64
#  17  2019-02     3728 non-null   int64
#  18  2019-03     3728 non-null   int64
# ...

# %%
print(sale_price_city['StateName'].unique())
sale_price_city['StateName'].value_counts()
# Out:
# ['New York' 'California' 'Texas' 'Illinois' 'Pennsylvania' 'Arizona'
#  'Nevada' 'Florida' 'Indiana' 'North Carolina' 'Ohio' 'Kentucky'
#  'Colorado' 'Washington' 'Tennessee' 'Massachusetts'
#  'District of Columbia' 'Oregon' 'Maryland' 'Wisconsin' 'Nebraska'
#  'New Mexico' 'Oklahoma' 'Georgia' 'Missouri' 'Virginia' 'Minnesota'
#  'Louisiana' 'Kansas' 'South Carolina' 'New Jersey' 'Alabama' 'Idaho'
#  'Iowa' 'Michigan' 'Utah' 'Arkansas' 'Rhode Island' 'Connecticut'
#  'Delaware' 'New Hampshire' 'Montana' 'Mississippi' 'North Dakota' 'Maine'
#  'Hawaii' 'West Virginia' 'South Dakota' 'Wyoming']
# StateName
# California              396
# Florida                 277
# Texas                   187
# New Jersey              183
# Illinois                172
# Ohio                    166
# Michigan                160
# Massachusetts           138
# New York                128
# Georgia                 119
# North Carolina          117
# Maryland                115
# ...

# %%
#convert all states to state abbreviations
state_abbreviations = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columnia' : 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii' : 'HI',
    'Idaho' : 'ID',
    'Illinois': 'IL',
    'Indiana' : 'IN',
    'Iowa' : 'IA',
    'Kansas' : 'KS',
    'Kentucky' : 'KY',
    'Louisiana' : 'LA',
    'Maine' : 'ME',
    'Maryland' : 'MD',
    'Massachusetts' : 'MA',
    'Michigan' : 'MI',
    'Minnesota' : 'MN',
    'Mississippi' : 'MS',
    'Missouri' : 'MO',
    'Montana' : 'MT',
    'Nebraska' : 'NE',
    'Nevada' : 'NV',
    'New Hampshire' : 'NH',
    'New Jersey' : 'NJ',
    'New Mexico' : 'NM',
    'New York' : 'NY',
    'North Carolina' : 'NC',
    'North Dakota' : 'ND',
    'Ohio' : 'OH',
    'Oklahoma' : 'OK',
    'Oregon' : 'OR',
    'Pennsylvania' : 'PA',
    'Rhode Island' : 'RI',
    'South Carolina' : 'SC',
    'South Dakota' : 'SD',
    'Tennessee' : 'TN',
    'Texas' : 'TX',
    'Utah' : 'UT',
    'Vermont' : 'VT',
    'Virginia' : 'VA',
    'Washington' : 'WA',
    'West Virginia' : 'WV',
    'Wisconsin' : 'WI',
    'Wyoming' : 'WY'
}

# %%
sale_price_city['StateName'] = sale_price_city['StateName'].str.strip().str.title()

sale_price_city['StateAbbreviation'] = sale_price_city['StateName'].rename(state_abbreviations)

# %%
sale_price_city
# Out:
#       Unnamed: 0  RegionID           RegionName       StateName  SizeRank  \
# 0              0      6181             New York        New York         1
# 1              1     12447          Los Angeles      California         2
# 2              2     39051              Houston           Texas         3
# 3              3     17426              Chicago        Illinois         4
# 4              4      6915          San Antonio           Texas         5
# ...          ...       ...                  ...             ...       ...
# 3723        3723     40400         Port Bolivar           Texas      3724
# 3724        3724    397820  Long Beach Township      New Jersey      3725
# 3725        3725     37346       Beech Mountain  North Carolina      3726
# 3726        3726     34991              Corolla  North Carolina      3727
# 3727        3727     52829            La Vernia           Texas      3728
#
#        2018-02  2018-03  2018-04  2018-05  2018-06  ...   2019-07   2019-08  \
# ...

# %%
sale_price_city['RegionID'].rename()
