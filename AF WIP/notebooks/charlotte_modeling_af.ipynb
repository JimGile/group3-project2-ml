# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import RegressorMixin, TransformerMixin
from sklearn.preprocessing import PowerTransformer, QuantileTransformer, StandardScaler
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, LinearRegression, ElasticNet, ElasticNetCV

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import cross_validate, KFold
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import TimeSeriesSplit

# %%
# Import custom classes
from supervised_model_pipeline import EdaToolbox, RegressorMultiModelEvaluator

# %% [markdown]
# ## Inspect the data

# %%
# Load the training data
cincinnati_file_path = '../../Data/Clean/combined/Cincinnati_combined.csv'
train_full_df = pd.read_csv(cincinnati_file_path)
train_full_df.head()
# Out:
#          DATE  MeanSalePrice  SalesCount  TotalTransactionValue  \
# 0  2008-04-30       155566.0      1939.0            278000302.0
# 1  2008-05-31       158474.0      2190.0            315975507.0
# 2  2008-06-30       164199.0      2286.0            352017758.0
# 3  2008-07-31       167422.0      2224.0            374100404.0
# 4  2008-08-31       166249.0      2193.0            371690060.0
#
#    HomeValueIndex  HomeValueIndexSmSa  MarketTempIdx  DaysToClose  \
# 0   154159.712821       157939.052238            NaN          NaN
# 1   154896.973753       157678.462221            NaN          NaN
# 2   155768.803669       157332.615865            NaN          NaN
# 3   156376.821297       157143.826684            NaN          NaN
# 4   155577.849578       156653.274461            NaN          NaN
#
#    DaysOnZillow  ListingPriceCutAmt  ...  PctSoldBelowList  MORTGAGE15US  \
# 0           NaN                 NaN  ...               NaN         5.465
# 1           NaN                 NaN  ...               NaN         5.600
# 2           NaN                 NaN  ...               NaN         5.910
# 3           NaN                 NaN  ...               NaN         5.972
# 4           NaN                 NaN  ...               NaN         6.025
#
#    MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.918            0.452    1047.0        -1.8
# 1         6.036            0.436    1045.6        -1.8
# 2         6.320            0.410    1041.2        -1.3
# 3         6.426            0.454    1045.1        -0.6
# 4         6.478            0.452    1043.8        -0.6
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                  1418.62244                  93.921524
# 1                  1418.62244                  93.921524
# 2                  1418.62244                  93.921524
# 3                  1418.62244                  93.921524
# 4                  1418.62244                  93.921524
#
#    PctBachelorsDegree_2019        CityName
# 0                43.323481  CINCINNATI, OH
# 1                43.323481  CINCINNATI, OH
# 2                43.323481  CINCINNATI, OH
# 3                43.323481  CINCINNATI, OH
# 4                43.323481  CINCINNATI, OH
#
# [5 rows x 26 columns]

# %%
# Remove columns that are too predictive
cols_to_remove = ['HomeValueIndexSmSa', 'HomeValueIndex']
train_full_df = train_full_df.drop(cols_to_remove, axis=1)

# %% [markdown]
# ## Create an EdaToolbox object

# %%
# Initialize the EdaToolbox
target_col = 'MeanSalePrice'
eda = EdaToolbox(train_full_df, target_column=target_col)

# %%
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#                            data_type  max_value_count_pct most_frequent_value  \
# CityName                      object             1.000000      CINCINNATI, OH
# DATE                          object             0.005128          2008-04-30
# People25PlusThousands_2019   float64             1.000000          1418.62244
# PctHighSchoolDiploma_2019    float64             1.000000           93.921524
# PctBachelorsDegree_2019      float64             1.000000           43.323481
#
#                             unique_values  missing_values  missing_values_pct  \
# CityName                                1               0                 0.0
# DATE                                  195               0                 0.0
# People25PlusThousands_2019              1               0                 0.0
# PctHighSchoolDiploma_2019               1               0                 0.0
# PctBachelorsDegree_2019                 1               0                 0.0
#
#                                                                 top_10_values
# CityName                    Index(['CINCINNATI, OH'], dtype='object', name...
# DATE                        Index(['2008-04-30', '2012-05-31', '2009-03-31...
# People25PlusThousands_2019  Index([1418.62244], dtype='float64', name='Peo...
# PctHighSchoolDiploma_2019   Index([93.921524], dtype='float64', name='PctH...
# PctBachelorsDegree_2019     Index([43.323481], dtype='float64', name='PctB...

# %%
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# %% [markdown]
# ## First check the distribution of the target column and select an appropriate target column transformer

# %%
# It is not normally distributed. It has a long tail to the right. Need to try different target transformations
target_transformation_dict: dict[str, TransformerMixin] = {
    'StandardScaler': StandardScaler(),
    'PowerTransformer': PowerTransformer(standardize=False),
    'QuantileTransformer': QuantileTransformer(output_distribution='normal', n_quantiles=500, random_state=42),
}

# %%
# Create a dict of models for preliminary testing of target transformations
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'Lasso Regression': Lasso(alpha=1.0, random_state=42),
    'ElasticNet Regression': ElasticNet(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(np.logspace(-6, 6, 25)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
kf_cv = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Use basic ordinal feature transformer
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.161782          0.160410          1.000307
# PowerTransformer              0.000000          0.000000          0.000000
# QuantileTransformer           0.359732          0.342376          1.065387
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.699692  0.225997      0.258608  0.160410
# PowerTransformer                  0.000000  0.000000      0.000000  0.000000
# QuantileTransformer               0.739473  0.335289      0.336325  0.358833
#
#                      HistGradientBoost
# StandardScaler                0.100555
# PowerTransformer              0.000000
# QuantileTransformer           0.342084

# %% [markdown]
# Note for Cincinatti dataset
# * HistGradientBoost shows best performance
# * Lasso Regression shows poor performance
# * Zero Errors in PowerTransformer: The zeros reported with the PowerTransformer across all models = suspicious

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018442995916220895, tolerance: 0.017302573836364486
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018218546170242433, tolerance: 0.017302573836364486
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017758408446312046, tolerance: 0.017302573836364486
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.160693          0.165886          0.976367
# PowerTransformer              0.000000          0.000000          0.000000
# QuantileTransformer           0.298456          0.212655          0.955622
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.673424  0.158338      0.159068  0.165886
# PowerTransformer                  0.000000  0.000000      0.000000  0.000000
# QuantileTransformer               0.619234  0.177962      0.186321  0.290236
#
#                      HistGradientBoost
# StandardScaler                0.105572
# PowerTransformer              0.000000
# QuantileTransformer           0.190636

# %% [markdown]
# Note for Cincinnati dataset
# * HistGradientBoost and LassoCV are most consistent top performers

# %%
# Use basic OHE feature transformer
eda.feature_transformer = eda.get_basic_ohe_feature_transformer()

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.252315          0.259291          1.000307
# PowerTransformer              0.000000          0.000000          0.000000
# QuantileTransformer           0.502262          0.476785          1.096834
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.771062  0.410569      0.459923  0.257039
# PowerTransformer                  0.000000  0.000000      0.000000  0.000000
# QuantileTransformer               0.832068  0.564346      0.573775  0.481116
#
#                      HistGradientBoost
# StandardScaler                0.169264
# PowerTransformer              0.000000
# QuantileTransformer           0.391060

# %% [markdown]
# Note for Cincinnati dataset
# * HistGradientBoost with the best result with lowest RMSE

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinally encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024962981127018224, tolerance: 0.017302573836364486
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.301982          0.326072          0.976367
# PowerTransformer              0.000000          0.000000          0.000000
# QuantileTransformer           0.595847          0.511914          1.000282
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.743423  0.323048      0.323918  0.319118
# PowerTransformer                  0.000000  0.000000      0.000000  0.000000
# QuantileTransformer               0.717471  0.473120      0.484253  0.533566
#
#                      HistGradientBoost
# StandardScaler                0.214808
# PowerTransformer              0.000000
# QuantileTransformer           0.231617

# %% [markdown]
# Note:
# * HistGradientBoost still has the best result, made even better than the last with lowest RMSE
# * Linear Regression, Ridge, Lasso, ElasticNet have higher RMSEs across transformations

# %% [markdown]
# ## Set the target and feature column tranformers
#
# * Use the PowerTransformer for the target column
# * Use the basic ordinal feature transformer

# %%
# Looks like the CV Models perform the best with a PowerTransformer.
# NOTE: These are pretty good RMSE scores with very basic encoding and no feature selection
eda.target_transformer = PowerTransformer(standardize=False)
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %% [markdown]
# ## Prepare the data for feature selection

# %%
# Gather initial column information sorted by data type and max value count to check for columns with high cardinality that can be pruned
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#                            data_type  max_value_count_pct most_frequent_value  \
# CityName                      object             1.000000      CINCINNATI, OH
# DATE                          object             0.005128          2008-04-30
# People25PlusThousands_2019   float64             1.000000          1418.62244
# PctHighSchoolDiploma_2019    float64             1.000000           93.921524
# PctBachelorsDegree_2019      float64             1.000000           43.323481
#
#                             unique_values  missing_values  missing_values_pct  \
# CityName                                1               0                 0.0
# DATE                                  195               0                 0.0
# People25PlusThousands_2019              1               0                 0.0
# PctHighSchoolDiploma_2019               1               0                 0.0
# PctBachelorsDegree_2019                 1               0                 0.0
#
#                                                                 top_10_values
# CityName                    Index(['CINCINNATI, OH'], dtype='object', name...
# DATE                        Index(['2008-04-30', '2012-05-31', '2009-03-31...
# People25PlusThousands_2019  Index([1418.62244], dtype='float64', name='Peo...
# PctHighSchoolDiploma_2019   Index([93.921524], dtype='float64', name='PctH...
# PctBachelorsDegree_2019     Index([43.323481], dtype='float64', name='PctB...

# %%
# Set pruning thresholds on the eda object according to column data type and cardinality for this dataset
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# %% [markdown]
# ## Feature analysis

# %%
# Frist check what the correlation and coefficient numbers look like
fa_df = eda.get_regression_feature_analysis_df()
fa_df.head()
# Out:
# Best RidgeCV alpha: 1e-06 (R^2 score:  1.00)
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                                       correlation_abs  coefficient_abs  \
# numerical__TotalTransactionValue             0.889606     1.806155e-10
# ordinal_date__DATE                           0.995549     1.335921e-09
# numerical__SalesCount                        0.587862     9.630279e-11
# numerical__NUM_JOBS                          0.839764     3.266318e-11
# numerical__NewConstructMeanSalePrice         0.289017     3.032734e-11
#
#                                           pval        vif  PCA1_abs  PCA2_abs  \
# numerical__TotalTransactionValue      0.822219  31.902751  0.174339  0.342890
# ordinal_date__DATE                    0.615031  18.926087  0.143562  0.229945
# numerical__SalesCount                 0.761940   6.669395  0.079194  0.450194
# numerical__NUM_JOBS                   0.981579   5.902741  0.117387  0.130752
# numerical__NewConstructMeanSalePrice  0.923183   7.708817  0.293629  0.198029
#
#                                          total
# numerical__TotalTransactionValue      1.406834
# ordinal_date__DATE                    1.369056
# numerical__SalesCount                 1.117251
# numerical__NUM_JOBS                   1.087903
# numerical__NewConstructMeanSalePrice  0.780675

# %%
# Plot out the highly correlated features
eda.plot_regression_feature_correlations(corr_min=0.2)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# Plot out the highly correlated features
eda.plot_regression_feature_correlations(corr_min=0.5)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# ## Perform unsupervised feature selection

# %%
# Try recursive feature elimination to find the optimal number of features for a linear regression model
regressor = LinearRegression()
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
rfecv_results_df.head()
# Out:
# Optimal number of features: 6
#    mean_test_score  std_test_score  split0_test_score  split1_test_score  \
# 0    -3.392696e-18    5.688215e-18      -3.619757e-20      -2.247672e-18
# 1    -4.396721e-18    6.667894e-18      -3.380103e-20      -4.707144e-18
# 2    -4.480935e-18    6.801097e-18      -3.438546e-20      -4.666333e-18
# 3    -7.510527e-20    6.523297e-20      -3.447772e-20      -1.693609e-20
# 4    -6.604229e-20    5.753106e-20      -3.017072e-20      -1.415772e-20
#
#    split2_test_score  split3_test_score  split4_test_score  selected  ranking  \
# 0      -1.369180e-20      -2.772909e-20      -1.463819e-17     False        3
# 1      -9.428866e-21      -5.305940e-21      -1.722792e-17     False        2
# 2      -1.521444e-20      -8.518396e-20      -1.760356e-17     False       13
# 3      -1.516068e-20      -1.594605e-19      -1.494914e-19     False       14
# 4      -1.391046e-20      -1.418295e-19      -1.301430e-19     False       10
#
#             feature_name
# 0             SalesCount
# 1  TotalTransactionValue
# 2          MarketTempIdx
# 3            DaysToClose
# 4           DaysOnZillow

# %%
rfe_lr_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE LR Selected Features: {rfe_lr_selected_features}")
# Out:
# RFE LR Selected Features: ['SaleToList' 'PctSoldAboveList' 'MORTGAGE15US' 'MORTGAGE30US'
#  'RATE_DIFFERENCE' 'DATE']

# %%
# Try recursive feature elimination to find the optimal number of features for a RidgeCV model
regressor = RidgeCV(alphas=np.logspace(-6, 6, num=6))
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
# Out:
# Optimal number of features: 4

# %%
rfe_ridge_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE Ridge Selected features: {rfe_ridge_selected_features}")
# Out:
# RFE Ridge Selected features: ['SaleToList' 'PctSoldAboveList' 'MORTGAGE30US' 'DATE']

# %%
# Try using forward SFS (SequentialFeatureSelector) to select the top 10 features
sfs_ridge_selected_features = eda.perform_unsupervised_regression_sfs_feature_selection(n_features=10)
print(f"SFS Ridge Selected Features: {sfs_ridge_selected_features}")
# Out:
# RidgeCV best alpha 1e-06
# Selected 10 features by forward sequential featureselection in 1.117 seconds
# SFS Ridge Selected Features: ['SalesCount', 'TotalTransactionValue', 'MarketTempIdx', 'SaleToList', 'NewConstructSalesCount', 'PctListingsPriceCut', 'PctSoldAboveList', 'RATE_DIFFERENCE', 'DATE', 'CityName']

# %%
# # Remove colinear features from the list of selected features
# # rfe_ridge_selected_features = [rfe_ridge_selected_features]
# rfe_ridge_selected_features = list(rfe_ridge_selected_features).remove('PctListingsPriceCut')
# rfe_ridge_selected_features

# %%
# Update EDA object with selected features from RFE
eda.selected_feature_list = rfe_ridge_selected_features

# Now get the list of selected ordinal columns
final_ordinal_cols = eda.get_final_ordinal_col_names(rfe_lr_selected_features)
len(final_ordinal_cols), final_ordinal_cols
# Out:
# (1, ['DATE'])

# %% [markdown]
# ## Perform final EDA with selected features and ordinal columns

# %%
# Reset transformer properties to use the selected columns and ordinal columns
eda.ordinal_encoding_col_dict = {}
for col_name in final_ordinal_cols:
    eda.add_ordinal_encoding_column(col_name, None)

eda.feature_transformer = eda.create_feature_transformer()
eda.feature_transformer
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(memory='named_steps',
#                                           steps=[('pruner',
#                                                   SimplePruner(infreq=0.95,
#                                                                pct_miss=0.8)),
#                                                  ('selector',
#                                                   SelectedFeaturesTransformer(selected_feature_list=array(['SaleToList', 'PctSoldAboveList', 'MORTGAGE30US', 'DATE'],
#       dtype=object))),
#                                                  ('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['SalesCount',...
#                                                                               '2010-01-31',
#                                                                               '2011-12-31',
#                                                                               '2008-11-30',
#                                                                               '2009-11-30',
#                                                                               '2011-11-30',
#                                                                               '2012-03-31',
#                                                                               '2010-04-30',
#                                                                               '2013-02-28',
#                                                                               '2010-03-31',
#                                                                               '2014-03-31',
#                                                                               '2014-02-28',
#                                                                               '2009-10-31',
#                                                                               '2013-03-31',
#                                                                               '2011-05-31',
#                                                                               '2009-06-30',
#                                                                               '2011-02-28',
#                                                                               '2014-01-31',
#                                                                               '2012-12-31', ...]],
#                                                                  encoded_missing_value=-2,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['DATE'])])

# %%
# Check feature analysis to ensure we have no multicollinearity (ie. no infinite vifs)
feature_analysis_df = eda.get_regression_feature_analysis_df()
feature_analysis_df.head()
# Out:
# Best RidgeCV alpha: 0.01 (R^2 score:  0.99)
#                              correlation_abs  coefficient_abs      pval  \
# ordinal_date__DATE                  0.995549     1.403526e-09  0.004386
# numerical__PctSoldAboveList         0.248515     2.609900e-10  0.897041
# numerical__SaleToList               0.243126     2.018364e-10  0.961822
# numerical__MORTGAGE30US             0.182491     3.955807e-11  0.549305
#
#                                    vif  PCA1_abs  PCA2_abs     total
# ordinal_date__DATE            1.062534  0.271578  0.580768  1.847895
# numerical__PctSoldAboveList  53.438508  0.665060  0.234725  1.148299
# numerical__SaleToList        53.516892  0.665765  0.228273  1.137164
# numerical__MORTGAGE30US       1.044048  0.201736  0.745322  1.129549

# %%
eda.plot_important_features(feature_analysis_df)

# %% [markdown]
# # Now do model analysis for multiple regression models

# %%
# Reload the data just to be safe
train_full_df = pd.read_csv(cincinnati_file_path)

# Create an instance of RegressorMultiModelEvaluator and set various properties
reg = RegressorMultiModelEvaluator(train_full_df, target_column=target_col)
reg.set_column_transformer_properties(selected_feature_list=eda.selected_feature_list, ordinal_feature_list=final_ordinal_cols)
reg.set_target_column_transformer(eda.target_transformer)

# %%
# Create a dict of models to test
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(alphas=np.logspace(-6, 6, num=7)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
# Evaluate the models
eval_df = reg.evaluate_models(model_dict)
eval_df
# Out:
# Number original X cols: 25
# Number scaled X cols: 4
#                    train_r2           mse        r2    r2_adj  lr_cv_mean  \
# model_name
# Ridge Regression   0.993861  1.030824e-20  0.994808  0.994197    0.994336
# RidgeCV            0.993981  1.047973e-20  0.994721  0.994100    0.994336
# Linear Regression  0.993981  1.048402e-20  0.994719  0.994098    0.994336
# LassoCV            0.993755  1.073151e-20  0.994594  0.993958    0.994336
# ElasticNetCV       0.993755  1.073151e-20  0.994594  0.993958    0.994336
# HistGradientBoost  0.994329  2.254296e-20  0.988645  0.987309    0.994336
#
#                    lr_cv_std      time  \
# model_name
# Ridge Regression    0.003774  0.007961
# RidgeCV             0.003774  0.008024
# Linear Regression   0.003774  0.008244
# LassoCV             0.003774  0.042151
# ElasticNetCV        0.003774  0.042670
# HistGradientBoost   0.003774  0.252470
#
#                                                               y_pred
# model_name
# Ridge Regression   [0.6444161993422014, 0.6444161971361791, 0.644...
# RidgeCV            [0.6444161993308147, 0.6444161971270377, 0.644...
# Linear Regression  [0.6444161993305589, 0.6444161971269498, 0.644...
# LassoCV            [0.6444161993654209, 0.6444161971262217, 0.644...
# ElasticNetCV       [0.6444161993654209, 0.6444161971262217, 0.644...
# HistGradientBoost  [0.6444161993030159, 0.6444161969156575, 0.644...

# %% [markdown]
# * RidgeCV a little better with balance of high r2 and r2_adj, low mse, consistent cross-validation results

# %%
reg.plot_model_evaluations()

# %% [markdown]
# * Looks overfit to me

# %%
# Get the best model
reg.best_model_name
# Out:
# 'Ridge Regression'

# %% [markdown]
# ## Now use the best model to predict on the test data

# %%
# Load test data from a different city
combined_file_path = '../../tw/combined_cities.csv'
test_full_df = pd.read_csv(combined_file_path)
test_full_df.head()
# Out:
#          DATE  MeanSalePrice  SalesCount  TotalTransactionValue  \
# 0  2008-04-30       200954.0      6463.0           1.235943e+09
# 1  2008-05-31       203419.0      6729.0           1.317605e+09
# 2  2008-06-30       205746.0      7047.0           1.388670e+09
# 3  2008-07-31       205553.0      7086.0           1.429205e+09
# 4  2008-08-31       202855.0      6383.0           1.388101e+09
#
#    HomeValueIndex  HomeValueIndexSmSa  MarketTempIdx  DaysToClose  \
# 0   185168.707578       189442.061550            NaN          NaN
# 1   185331.245765       188426.220342            NaN          NaN
# 2   185185.095114       187437.288971            NaN          NaN
# 3   184692.089305       186253.861325            NaN          NaN
# 4   183376.364934       184882.815462            NaN          NaN
#
#    DaysOnZillow  ListingPriceCutAmt  ...  PctSoldBelowList  MORTGAGE15US  \
# 0           NaN                 NaN  ...               NaN         5.465
# 1           NaN                 NaN  ...               NaN         5.600
# 2           NaN                 NaN  ...               NaN         5.910
# 3           NaN                 NaN  ...               NaN         5.972
# 4           NaN                 NaN  ...               NaN         6.025
#
#    MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.918            0.452    2454.9        -3.5
# 1         6.036            0.436    2450.9        -6.2
# 2         6.320            0.410    2442.4        -6.1
# 3         6.426            0.454    2434.6        -6.8
# 4         6.478            0.452    2429.3        -7.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                  4414.04779                  89.810682
# 1                  4414.04779                  89.810682
# 2                  4414.04779                  89.810682
# 3                  4414.04779                  89.810682
# 4                  4414.04779                  89.810682
#
#    PctBachelorsDegree_2019     CityName
# 0                41.859123  ATLANTA, GA
# 1                41.859123  ATLANTA, GA
# 2                41.859123  ATLANTA, GA
# 3                41.859123  ATLANTA, GA
# 4                41.859123  ATLANTA, GA
#
# [5 rows x 26 columns]

# %%
# Drop target column
combined_file_df = test_full_df[target_col]
test_full_df = test_full_df.drop([target_col])
test_full_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Drop target column
#       2 combined_file_df = test_full_df[target_col]
# ----> 3 test_full_df = test_full_df.drop([target_col])
#       4 test_full_df.head()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['MeanSalePrice'] not found in axis"

# %%
# Make predictions with HistGradientBoost
#reg.best_model = model_dict['Linear Regression']
lr_predictions = reg.predict(test_full_df)
lr_predictions
# Out:
# array([196606.75008567, 199628.83459339, 201684.87637794, 200652.66189617,
#        198613.30124795, 191729.23822738, 186125.99765161, 178196.75506636,
#        174843.94760544, 162387.25676913, 157376.17426905, 151286.45251209,
#        154622.31205013, 161655.94872807, 175672.67480683, 181653.12194711,
#        184316.01967694, 179911.72165015, 177349.01277639, 176507.67475473,
#        173205.05438723, 170792.17534001, 166887.89797862, 165365.84205734,
#        172394.7619298 , 179050.96870049, 182533.90984736, 183421.51819959,
#        180779.08279687, 174021.4286768 , 160208.97338809, 155303.5431149 ,
#        156680.42756807, 160929.87133251, 155989.5661641 , 153274.0432015 ,
#        151944.39977619, 158076.85378968, 169213.1825001 , 169999.75961204,
#        163865.77279975, 149984.0913178 , 149339.59270538, 148063.75151315,
#        147432.32723577, 146805.18017669, 145563.55956816, 146182.27068307,
#        148699.49313454, 150633.03055772, 158782.51424193, 167657.30942395,
#        166124.09416407, 159493.2043357 , 153945.82716293, 152606.91546115,
#        164613.08644248, 163123.84729497, 168432.38514103, 171590.48931142,
#        185217.48793969, 193656.87180116, 197605.9699513 , 208059.68574991,
#        203774.84646826, 195615.55230211, 192689.2165387 , 188894.53752408,
#        190776.85354845, 187964.44519565, 187041.62449661, 189831.98032923,
#        194632.28849909, 211368.29155624, 214761.47885606, 224246.70038524,
#        223024.92440414, 212489.81085778, 209153.33591025, 202725.5725963 ,
#        205899.51778002, 206975.11406649, 204832.79529374, 210256.16913703,
#        213620.83632354, 229242.03407294, 241151.81596592, 243932.43225503,
#        238421.33607637, 226722.46064487, 219422.49608175, 217072.06701072,
#        221813.71469766, 220612.94629085, 215911.85100774, 218242.24280746,
#        225479.16952358, 237074.51075682, 245341.937384  , 255582.32612104,
#        246764.45671554, 239780.38688727, 231806.49153403, 230518.58407673,
#        233105.89554572, 234416.93738548, 227976.70455419, 235739.76054111,
#        242535.77852388, 258633.55185087, 264912.81002934, 276502.25505616,
#        268143.98622557, 260180.97694065, 254078.15166197, 248200.15568514,
#        251111.76774591, 249649.20241078, 252588.02533358, 256722.36769939,
#        269693.4372074 , 277351.49729541, 286358.2872998 , 287807.09084735,
#        277551.5526953 , 269945.31910888, 261411.62012282, 265073.46083701,
#        256666.53702936, 252741.98353903, 252257.20059316, 262564.11784594,
#        267649.54800132, 285024.2618572 , 290041.9492257 , 292263.22762814,
#        287630.1424351 , 280384.23093495, 269343.48841537, 265014.6802933 ,
#        269998.5091989 , 272678.90187093, 281377.67225565, 292056.1855291 ,
#        303035.8855132 , 304878.90562913, 303984.88875345, 303250.10194649,
#        305718.30999139, 319044.43166444, 326927.35578931, 325298.22450199,
#        326055.15703864, 326956.72236415, 336454.90483097, 347436.70468339,
#        352478.08704808, 355993.4362771 , 359530.29492126, 371532.2527666 ,
#        368952.728626  , 361910.13216529, 366339.76054222, 377316.28764171,
#        380983.75010471, 370307.3693719 , 378960.08925185, 388542.99799712,
#        399944.50329197, 411127.37391515, 431533.369594  , 439649.93602772,
#        419983.44616284, 405641.00297947, 398244.16714381, 388571.8487301 ,
#        386954.49457904, 380086.39389045, 379223.04909147, 385567.96934435,
#        402133.29974289, 427278.38886396, 449828.05924428, 459793.4485282 ,
#        454824.9639284 , 437506.9937314 , 424962.66634926, 420757.20162606,
#        414903.148367  , 399429.55260236, 399726.74051211, 407867.20980978,
#        434268.83790583, 444497.66774469, 447708.9860597 ])

# %%
# Plot Actual vs Predictions
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Atlanta Predictions vs Actuals")
ax.plot(
    atlanta_actual_values,
    "x-",
    alpha=0.2,
    label=f"Actual {target_col} values",
    color="black",
)
ax.plot(lr_predictions, "x-", label="HistGradientBoost")
_ = ax.legend()
