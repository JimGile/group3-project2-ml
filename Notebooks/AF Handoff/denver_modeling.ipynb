# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import RegressorMixin, TransformerMixin
from sklearn.preprocessing import PowerTransformer, QuantileTransformer, StandardScaler
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, LinearRegression, ElasticNet, ElasticNetCV

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import cross_validate, KFold
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import TimeSeriesSplit

# %%
# Import custom classes
from supervised_model_pipeline import EdaToolbox, RegressorMultiModelEvaluator

# %% [markdown]
# ## Inspect the data

# %%
# Load the training data
denver_file_path = '../../Data/Clean/combined/Denver_combined.csv'
train_full_df = pd.read_csv(denver_file_path)
train_full_df.head()
# Out:
#          DATE  MeanSalePrice  SalesCount  TotalTransactionValue  \
# 0  2008-04-30       245069.0      4305.0           9.275848e+08
# 1  2008-05-31       242919.0      4779.0           1.043794e+09
# 2  2008-06-30       245529.0      4789.0           1.136320e+09
# 3  2008-07-31       247607.0      4922.0           1.195890e+09
# 4  2008-08-31       246384.0      4333.0           1.154412e+09
#
#    HomeValueIndex  HomeValueIndexSmSa  MarketTempIdx  DaysToClose  \
# 0   239786.727396       243635.279120            NaN          NaN
# 1   240755.620219       242719.130794            NaN          NaN
# 2   241296.223700       241952.165191            NaN          NaN
# 3   240843.494803       240801.464621            NaN          NaN
# 4   239424.931087       239672.270501            NaN          NaN
#
#    DaysOnZillow  ListingPriceCutAmt  ...  PctSoldBelowList  MORTGAGE15US  \
# 0           NaN                 NaN  ...               NaN         5.465
# 1           NaN                 NaN  ...               NaN         5.600
# 2           NaN                 NaN  ...               NaN         5.910
# 3           NaN                 NaN  ...               NaN         5.972
# 4           NaN                 NaN  ...               NaN         6.025
#
#    MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.918            0.452    1259.0         1.0
# 1         6.036            0.436    1256.8        -1.0
# 2         6.320            0.410    1258.2        -0.6
# 3         6.426            0.454    1256.1        -1.0
# 4         6.478            0.452    1256.2        -0.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                   2434.5429                  91.688128
# 1                   2434.5429                  91.688128
# 2                   2434.5429                  91.688128
# 3                   2434.5429                  91.688128
# 4                   2434.5429                  91.688128
#
#    PctBachelorsDegree_2019    CityName
# 0                49.747029  DENVER, CO
# 1                49.747029  DENVER, CO
# 2                49.747029  DENVER, CO
# 3                49.747029  DENVER, CO
# 4                49.747029  DENVER, CO
#
# [5 rows x 26 columns]

# %%
# Remove columns that are too predictive
cols_to_remove = ['HomeValueIndexSmSa', 'HomeValueIndex']
train_full_df = train_full_df.drop(cols_to_remove, axis=1)

# %% [markdown]
# ## Create an EdaToolbox object

# %%
# Initialize the EdaToolbox
target_col = 'MeanSalePrice'
eda = EdaToolbox(train_full_df, target_column=target_col)

# %%
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#                            data_type  max_value_count_pct most_frequent_value  \
# CityName                      object             1.000000          DENVER, CO
# DATE                          object             0.005128          2008-04-30
# People25PlusThousands_2019   float64             1.000000           2434.5429
# PctHighSchoolDiploma_2019    float64             1.000000           91.688128
# PctBachelorsDegree_2019      float64             1.000000           49.747029
#
#                             unique_values  missing_values  missing_values_pct  \
# CityName                                1               0                 0.0
# DATE                                  195               0                 0.0
# People25PlusThousands_2019              1               0                 0.0
# PctHighSchoolDiploma_2019               1               0                 0.0
# PctBachelorsDegree_2019                 1               0                 0.0
#
#                                                                 top_10_values
# CityName                    Index(['DENVER, CO'], dtype='object', name='Ci...
# DATE                        Index(['2008-04-30', '2012-05-31', '2009-03-31...
# People25PlusThousands_2019  Index([2434.5429], dtype='float64', name='Peop...
# PctHighSchoolDiploma_2019   Index([91.688128], dtype='float64', name='PctH...
# PctBachelorsDegree_2019     Index([49.747029], dtype='float64', name='PctB...

# %%
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# %% [markdown]
# ## First check the distribution of the target column and select an appropriate target column transformer

# %%
# It is not normally distributed. It has a long tail to the right. Need to try different target transformations
target_transformation_dict: dict[str, TransformerMixin] = {
    'StandardScaler': StandardScaler(),
    'PowerTransformer': PowerTransformer(standardize=False),
    'QuantileTransformer': QuantileTransformer(output_distribution='normal', n_quantiles=500, random_state=42),
}

# %%
# Create a dict of models for preliminary testing of target transformations
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'Lasso Regression': Lasso(alpha=1.0, random_state=42),
    'ElasticNet Regression': ElasticNet(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(np.logspace(-6, 6, 25)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
kf_cv = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Use basic ordinal feature transformer
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015986157495760267, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02118180267850711, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021905937830871025, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021590484701114576, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021016984056875465, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020364738532634874, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019681107899426564, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016221481512717517, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0201903679662081, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03171165516532426, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0276000865747541, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03284887476392839, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033572551977005816, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033164650732739887, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03245702364703362, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03165413337416112, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016892696882791824, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018600628503329553, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027393913428120698, tolerance: 0.019417286040642214
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028915346056059832, tolerance: 0.019417286040642214
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028693548795651225, tolerance: 0.019417286040642214
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027355068787976222, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.014339410294120114, tolerance: 0.009130961036912109
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028641189342380358, tolerance: 0.016059567587093766
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03237654876580365, tolerance: 0.016059567587093766
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02726115434133014, tolerance: 0.017176190174603513
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026528610427863697, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027852976844606303, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02715572126603405, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026451397066473703, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02574950329272241, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024379157972383325, tolerance: 0.020184574331343155
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02796321714900074, tolerance: 0.020184574331343155
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028232878397542294, tolerance: 0.020184574331343155
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027684058056404837, tolerance: 0.020184574331343155
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.102294          0.101943          1.001399
# PowerTransformer              0.000144          0.000160          0.002421
# QuantileTransformer           0.360410          0.346947          1.063085
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.659355  0.106030      0.099204  0.101047
# PowerTransformer                  0.002421  0.000152      0.000152  0.000144
# QuantileTransformer               0.728569  0.330695      0.330933  0.349981
#
#                      HistGradientBoost
# StandardScaler                0.046733
# PowerTransformer              0.000110
# QuantileTransformer           0.306000

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02050862786601826, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024420267434889453, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024486018662337017, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02381949728848909, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023009078247234527, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022147078122625175, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02103451641785714, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02593589498891191, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026666865461419498, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026238033961947238, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01767227283177064, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026312679672120254, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027756045160103326, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02752165028556064, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0423005027539034, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02647621295609781, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021657529204141213, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02039757004948939, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019697115799623077, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01908036137396607, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01925285121188125, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02689757920433067, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028241998954619874, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02804743806417065, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027472194212883494, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02678682690660139, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02606068363426317, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025317133651874713, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.102488          0.098333          0.987266
# PowerTransformer              0.000152          0.000161          0.002355
# QuantileTransformer           0.312930          0.252940          1.003459
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.653573  0.103120      0.099920  0.099681
# PowerTransformer                  0.002355  0.000157      0.000157  0.000151
# QuantileTransformer               0.663008  0.167532      0.173911  0.239239
#
#                      HistGradientBoost
# StandardScaler                0.039813
# PowerTransformer              0.000101
# QuantileTransformer           0.212164

# %%
# Use basic OHE feature transformer
eda.feature_transformer = eda.get_basic_ohe_feature_transformer()

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02240587238257774, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02629462842916297, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02132117199196415, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019078013093954738, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01827601314916194, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01769248191389039, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022449203807038742, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024110091003914036, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023903726568757833, tolerance: 0.00935827300021834
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03663392828905998, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03030258658418461, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027134206984374742, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025911410445718985, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024993340862064173, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024127530804427977, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03439434108614137, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.037407518685157015, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03722550676505065, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021932901118915993, tolerance: 0.018156525677429713
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03424302732807405, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03490448362045839, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02129553827104047, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02883063789074569, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030717413789719927, tolerance: 0.019514805279635453
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02132175833027361, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024388683304843894, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024891909931859857, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022468015722541423, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02101284868623665, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020319550255987195, tolerance: 0.009432712865027773
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0324542630606004, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.035049569387204826, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03499378289139088, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03426998079937249, tolerance: 0.020578215271411963
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028443157836512967, tolerance: 0.009130961036912109
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.036215380043152834, tolerance: 0.009130961036912109
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025011242909283027, tolerance: 0.01613191491598543
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.036400621353571694, tolerance: 0.01613191491598543
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.039247588380153076, tolerance: 0.01613191491598543
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022696397047617722, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026971012519943827, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02738599951227272, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02690467620725201, tolerance: 0.018738873767473886
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.212704          0.212297          1.001399
# PowerTransformer              0.000490          0.000488          0.002421
# QuantileTransformer           0.451849          0.442372          1.095851
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.726922  0.349667      0.378371  0.215122
# PowerTransformer                  0.002421  0.000683      0.000683  0.000501
# QuantileTransformer               0.803178  0.543734      0.548439  0.448152
#
#                      HistGradientBoost
# StandardScaler                0.115293
# PowerTransformer              0.000380
# QuantileTransformer           0.338063

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02237496646107573, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022601331678735903, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02109745449136824, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019458626131051204, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01865630862980794, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01797650019076258, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017324109141981126, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02567248395924082, tolerance: 0.01711694840564511
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021165910345008143, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023258415703882207, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025645320950665962, tolerance: 0.01379891228181215
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05072729248580643, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06317756327227642, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04503164699498896, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024721705380159165, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021125644213544348, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01994624549013224, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019167596290444067, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018470095642250328, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.037802277942468265, tolerance: 0.017315139296859457
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029496891711538353, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03174989058675237, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03148812924138866, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029050602362683975, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020148323033076565, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01830980710585095, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017484971939715876, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01682616859258701, tolerance: 0.016549203700666194
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (500) is greater than the total number of samples (195). n_quantiles is set to n_samples.
#   warnings.warn(
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.200035          0.195907          0.987266
# PowerTransformer              0.000472          0.000477          0.002355
# QuantileTransformer           0.411798          0.371610          1.041754
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.719048  0.196792      0.196583  0.199607
# PowerTransformer                  0.002355  0.000479      0.000479  0.000477
# QuantileTransformer               0.734977  0.336833      0.336310  0.371610
#
#                      HistGradientBoost
# StandardScaler                0.064513
# PowerTransformer              0.000456
# QuantileTransformer           0.270631

# %% [markdown]
# ## Set the target and feature column tranformers
#
# * Use the PowerTransformer for the target column
# * Use the basic ordinal feature transformer

# %%
# Looks like the CV Models perform the best with a PowerTransformer.
# NOTE: These are pretty good RMSE scores with very basic encoding and no feature selection
eda.target_transformer = PowerTransformer(standardize=False)
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %% [markdown]
# ## Prepare the data for feature selection

# %%
# Gather initial column information sorted by data type and max value count to check for columns with high cardinality that can be pruned
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#                            data_type  max_value_count_pct most_frequent_value  \
# CityName                      object             1.000000          DENVER, CO
# DATE                          object             0.005128          2008-04-30
# People25PlusThousands_2019   float64             1.000000           2434.5429
# PctHighSchoolDiploma_2019    float64             1.000000           91.688128
# PctBachelorsDegree_2019      float64             1.000000           49.747029
#
#                             unique_values  missing_values  missing_values_pct  \
# CityName                                1               0                 0.0
# DATE                                  195               0                 0.0
# People25PlusThousands_2019              1               0                 0.0
# PctHighSchoolDiploma_2019               1               0                 0.0
# PctBachelorsDegree_2019                 1               0                 0.0
#
#                                                                 top_10_values
# CityName                    Index(['DENVER, CO'], dtype='object', name='Ci...
# DATE                        Index(['2008-04-30', '2012-05-31', '2009-03-31...
# People25PlusThousands_2019  Index([2434.5429], dtype='float64', name='Peop...
# PctHighSchoolDiploma_2019   Index([91.688128], dtype='float64', name='PctH...
# PctBachelorsDegree_2019     Index([49.747029], dtype='float64', name='PctB...

# %%
# Set pruning thresholds on the eda object according to column data type and cardinality for this dataset
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# %% [markdown]
# ## Feature analysis

# %%
# Frist check what the correlation and coefficient numbers look like
fa_df = eda.get_regression_feature_analysis_df()
fa_df.head()
# Out:
# Best RidgeCV alpha: 0.01 (R^2 score:  1.00)
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                                       correlation_abs  coefficient_abs  \
# ordinal_date__DATE                           0.996436         0.002019
# numerical__NUM_JOBS                          0.954660         0.000171
# numerical__TotalTransactionValue             0.838063         0.000287
# numerical__NewConstructMeanSalePrice         0.244011         0.000002
# numerical__DaysToClose                       0.206733         0.000002
#
#                                           pval        vif  PCA1_abs  PCA2_abs  \
# ordinal_date__DATE                    0.429273  26.018112  0.092671  0.176204
# numerical__NUM_JOBS                   0.982616  15.817053  0.053392  0.195729
# numerical__TotalTransactionValue      0.866099  29.194217  0.182542  0.039204
# numerical__NewConstructMeanSalePrice  0.905697   6.106051  0.127860  0.425397
# numerical__DaysToClose                0.985549   6.079443  0.204036  0.350230
#
#                                          total
# ordinal_date__DATE                    1.267330
# numerical__NUM_JOBS                   1.203953
# numerical__TotalTransactionValue      1.060097
# numerical__NewConstructMeanSalePrice  0.797270
# numerical__DaysToClose                0.761002

# %%
# Plot out the highly correlated features
eda.plot_regression_feature_correlations(corr_min=0.2)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# ## Perform unsupervised feature selection

# %%
# Try recursive feature elimination to find the optimal number of features for a linear regression model
regressor = LinearRegression()
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
rfecv_results_df.head()
# Out:
# Optimal number of features: 11
#    mean_test_score  std_test_score  split0_test_score  split1_test_score  \
# 0    -1.446627e-05    1.919817e-05      -2.423091e-05      -6.008279e-08
# 1    -1.895393e-05    2.364710e-05      -3.983595e-05      -5.622215e-08
# 2    -1.915831e-05    2.394571e-05      -3.957218e-05      -8.348154e-08
# 3    -1.208198e-07    8.171272e-08      -2.742788e-07      -8.367302e-08
# 4    -1.215408e-07    1.028688e-07      -3.215172e-07      -5.926304e-08
#
#    split2_test_score  split3_test_score  split4_test_score  selected  ranking  \
# 0      -2.567713e-08      -3.478394e-08      -4.797990e-05     False        3
# 1      -2.579526e-08      -3.127013e-08      -5.482040e-05      True        1
# 2      -2.564509e-08      -1.083286e-07      -5.600191e-05     False        7
# 3      -3.078733e-08      -1.091197e-07      -1.062400e-07     False        8
# 4      -3.306086e-08      -9.759201e-08      -9.627104e-08      True        1
#
#             feature_name
# 0             SalesCount
# 1  TotalTransactionValue
# 2          MarketTempIdx
# 3            DaysToClose
# 4           DaysOnZillow

# %%
rfe_lr_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE LR Selected Features: {rfe_lr_selected_features}")
# Out:
# RFE LR Selected Features: ['TotalTransactionValue' 'DaysOnZillow' 'ListingPriceCutPct'
#  'PctListingsPriceCut' 'PctSoldAboveList' 'PctSoldBelowList'
#  'MORTGAGE15US' 'MORTGAGE30US' 'RATE_DIFFERENCE' 'NUM_JOBS' 'DATE']

# %%
# Try recursive feature elimination to find the optimal number of features for a RidgeCV model
regressor = RidgeCV(alphas=np.logspace(-6, 6, num=5))
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
# Out:
# Optimal number of features: 10

# %%
rfe_ridge_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE Ridge Selected features: {rfe_ridge_selected_features}")
# Out:
# RFE Ridge Selected features: ['TotalTransactionValue' 'DaysOnZillow' 'ListingPriceCutPct'
#  'PctListingsPriceCut' 'PctSoldAboveList' 'PctSoldBelowList'
#  'MORTGAGE15US' 'MORTGAGE30US' 'NUM_JOBS' 'DATE']

# %%
# Try using forward SFS (SequentialFeatureSelector) to select the top 28 features
sfs_ridge_selected_features = eda.perform_unsupervised_regression_sfs_feature_selection(n_features=10)
print(f"SFS Ridge Selected Features: {sfs_ridge_selected_features}")
# Out:
# RidgeCV best alpha 0.001
# Selected 10 features by forward sequential featureselection in 1.196 seconds
# SFS Ridge Selected Features: ['SalesCount', 'DaysOnZillow', 'ListingPriceCutPct', 'NewConstructSalesCount', 'PctSoldBelowList', 'RATE_DIFFERENCE', 'NUM_JOBS', 'GROWTH_PCT', 'DATE', 'CityName']

# %%
# Remove colinear features from the list of selected features
# rfe_ridge_selected_features = [rfe_ridge_selected_features]
rfe_ridge_selected_features = list(rfe_ridge_selected_features)
rfe_ridge_selected_features.remove('PctSoldAboveList')
rfe_ridge_selected_features.remove('MORTGAGE15US')
rfe_ridge_selected_features
# Out:
# ['TotalTransactionValue',
#  'DaysOnZillow',
#  'ListingPriceCutPct',
#  'PctListingsPriceCut',
#  'PctSoldBelowList',
#  'MORTGAGE30US',
#  'NUM_JOBS',
#  'DATE']

# %%
# Update EDA object with selected features from RFE
eda.selected_feature_list = rfe_ridge_selected_features

# Now get the list of selected ordinal columns
final_ordinal_cols = eda.get_final_ordinal_col_names(rfe_lr_selected_features)
len(final_ordinal_cols), final_ordinal_cols
# Out:
# (1, ['DATE'])

# %% [markdown]
# ## Perform final EDA with selected features and ordinal columns

# %%
# Reset transformer properties to use the selected columns and ordinal columns
eda.ordinal_encoding_col_dict = {}
for col_name in final_ordinal_cols:
    eda.add_ordinal_encoding_column(col_name, None)

eda.feature_transformer = eda.create_feature_transformer()
eda.feature_transformer
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(memory='named_steps',
#                                           steps=[('pruner',
#                                                   SimplePruner(infreq=0.95,
#                                                                pct_miss=0.8)),
#                                                  ('selector',
#                                                   SelectedFeaturesTransformer(selected_feature_list=['TotalTransactionValue',
#                                                                                                      'DaysOnZillow',
#                                                                                                      'ListingPriceCutPct',
#                                                                                                      'PctListingsPriceCut',
#                                                                                                      'PctSoldBelowList',
#                                                                                                      'MORTGAGE30US',
#                                                                                                      'NUM_JOBS',
#                                                                                                      'DATE'])),
#                                                  ('imputer', SimpleI...
#                                                                               '2010-01-31',
#                                                                               '2008-09-30',
#                                                                               '2010-03-31',
#                                                                               '2011-03-31',
#                                                                               '2010-02-28',
#                                                                               '2010-04-30',
#                                                                               '2009-09-30',
#                                                                               '2008-05-31',
#                                                                               '2011-04-30',
#                                                                               '2009-07-31',
#                                                                               '2011-02-28',
#                                                                               '2008-04-30',
#                                                                               '2010-05-31',
#                                                                               '2008-06-30',
#                                                                               '2009-08-31',
#                                                                               '2008-08-31',
#                                                                               '2008-07-31',
#                                                                               '2011-05-31', ...]],
#                                                                  encoded_missing_value=-2,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['DATE'])])

# %%
# Check feature analysis to ensure we have no multicollinearity (ie. no infinite vifs)
feature_analysis_df = eda.get_regression_feature_analysis_df()
feature_analysis_df.head()
# Out:
# Best RidgeCV alpha: 1e-06 (R^2 score:  1.00)
#                                   correlation_abs  coefficient_abs      pval  \
# ordinal_date__DATE                       0.996436         0.002090  0.210123
# numerical__NUM_JOBS                      0.954660         0.000157  0.954832
# numerical__TotalTransactionValue         0.838063         0.000195  0.950792
# numerical__PctSoldBelowList              0.095451         0.000122  0.908569
# numerical__DaysOnZillow                  0.072127         0.000048  0.892728
#
#                                         vif  PCA1_abs  PCA2_abs     total
# ordinal_date__DATE                14.474358  0.256018  0.534230  1.788774
# numerical__NUM_JOBS               13.068360  0.201056  0.563570  1.719444
# numerical__TotalTransactionValue   8.382517  0.383366  0.388607  1.610232
# numerical__PctSoldBelowList       31.325212  0.484682  0.233860  0.814116
# numerical__DaysOnZillow           16.745793  0.456604  0.211226  0.740005

# %%
eda.plot_important_features(feature_analysis_df)

# %% [markdown]
# # Now do model analysis for multiple regression models

# %%
# Reload the data just to be safe
train_full_df = pd.read_csv(denver_file_path)

# Create an instance of RegressorMultiModelEvaluator and set various properties
reg = RegressorMultiModelEvaluator(train_full_df, target_column=target_col)
reg.set_column_transformer_properties(selected_feature_list=eda.selected_feature_list, ordinal_feature_list=final_ordinal_cols)
reg.set_target_column_transformer(eda.target_transformer)

# %%
# Create a dict of models to test
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(alphas=np.logspace(-6, 6, num=7)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
# Evaluate the models
eval_df = reg.evaluate_models(model_dict)
eval_df
# Out:
# Number original X cols: 25
# Number scaled X cols: 8
#                    train_r2           mse        r2    r2_adj  lr_cv_mean  \
# model_name
# HistGradientBoost  0.998410  2.250741e-08  0.995916  0.994827    0.991069
# Ridge Regression   0.995909  3.124226e-08  0.994331  0.992819    0.991069
# Linear Regression  0.996193  3.243271e-08  0.994115  0.992545    0.991069
# RidgeCV            0.996193  3.243283e-08  0.994115  0.992545    0.991069
# ElasticNetCV       0.996151  3.330167e-08  0.993957  0.992345    0.991069
# LassoCV            0.996151  3.330299e-08  0.993957  0.992345    0.991069
#
#                    lr_cv_std      time  \
# model_name
# HistGradientBoost   0.004267  0.302946
# Ridge Regression    0.004267  0.007770
# Linear Regression   0.004267  0.008338
# RidgeCV             0.004267  0.009051
# ElasticNetCV        0.004267  0.043610
# LassoCV             0.004267  0.044234
#
#                                                               y_pred
# model_name
# HistGradientBoost  [2.552913162429354, 2.548636707618142, 2.55382...
# Ridge Regression   [2.552927454239785, 2.5485254556003376, 2.5540...
# Linear Regression  [2.5528824087759188, 2.548531198687603, 2.5540...
# RidgeCV            [2.552882409471042, 2.548531196920406, 2.55408...
# ElasticNetCV       [2.552903638375998, 2.548521290862036, 2.55408...
# LassoCV            [2.552903620547811, 2.5485212929854857, 2.5540...

# %%
reg.plot_model_evaluations()

# %%
# Get the best model
reg.best_model_name
# Out:
# 'HistGradientBoost'

# %% [markdown]
# ## Now use the best model to predict on the test data

# %%
# Load test data from a different city
combined_file_path = '../../Data/Clean/combined/all_cities_combined.csv'
test_full_df = pd.read_csv(combined_file_path)
test_full_df.head()
# Out:
#          DATE  MeanSalePrice  SalesCount  TotalTransactionValue  \
# 0  2008-04-30       200954.0      6463.0           1.235943e+09
# 1  2008-05-31       203419.0      6729.0           1.317605e+09
# 2  2008-06-30       205746.0      7047.0           1.388670e+09
# 3  2008-07-31       205553.0      7086.0           1.429205e+09
# 4  2008-08-31       202855.0      6383.0           1.388101e+09
#
#    HomeValueIndex  HomeValueIndexSmSa  MarketTempIdx  DaysToClose  \
# 0   185168.707578       189442.061550            NaN          NaN
# 1   185331.245765       188426.220342            NaN          NaN
# 2   185185.095114       187437.288971            NaN          NaN
# 3   184692.089305       186253.861325            NaN          NaN
# 4   183376.364934       184882.815462            NaN          NaN
#
#    DaysOnZillow  ListingPriceCutAmt  ...  PctSoldBelowList  MORTGAGE15US  \
# 0           NaN                 NaN  ...               NaN         5.465
# 1           NaN                 NaN  ...               NaN         5.600
# 2           NaN                 NaN  ...               NaN         5.910
# 3           NaN                 NaN  ...               NaN         5.972
# 4           NaN                 NaN  ...               NaN         6.025
#
#    MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.918            0.452    2454.9        -3.5
# 1         6.036            0.436    2450.9        -6.2
# 2         6.320            0.410    2442.4        -6.1
# 3         6.426            0.454    2434.6        -6.8
# 4         6.478            0.452    2429.3        -7.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                  4414.04779                  89.810682
# 1                  4414.04779                  89.810682
# 2                  4414.04779                  89.810682
# 3                  4414.04779                  89.810682
# 4                  4414.04779                  89.810682
#
#    PctBachelorsDegree_2019     CityName
# 0                41.859123  ATLANTA, GA
# 1                41.859123  ATLANTA, GA
# 2                41.859123  ATLANTA, GA
# 3                41.859123  ATLANTA, GA
# 4                41.859123  ATLANTA, GA
#
# [5 rows x 26 columns]

# %%
# Drop target column
combined_file_df = test_full_df[target_col]
test_full_df = test_full_df.drop(columns=[target_col]) 
test_full_df.head()
# Out:
#          DATE  SalesCount  TotalTransactionValue  HomeValueIndex  \
# 0  2008-04-30      6463.0           1.235943e+09   185168.707578
# 1  2008-05-31      6729.0           1.317605e+09   185331.245765
# 2  2008-06-30      7047.0           1.388670e+09   185185.095114
# 3  2008-07-31      7086.0           1.429205e+09   184692.089305
# 4  2008-08-31      6383.0           1.388101e+09   183376.364934
#
#    HomeValueIndexSmSa  MarketTempIdx  DaysToClose  DaysOnZillow  \
# 0       189442.061550            NaN          NaN           NaN
# 1       188426.220342            NaN          NaN           NaN
# 2       187437.288971            NaN          NaN           NaN
# 3       186253.861325            NaN          NaN           NaN
# 4       184882.815462            NaN          NaN           NaN
#
#    ListingPriceCutAmt  ListingPriceCutPct  ...  PctSoldBelowList  \
# 0                 NaN                 NaN  ...               NaN
# 1                 NaN                 NaN  ...               NaN
# 2                 NaN                 NaN  ...               NaN
# 3                 NaN                 NaN  ...               NaN
# 4                 NaN                 NaN  ...               NaN
#
#    MORTGAGE15US  MORTGAGE30US  RATE_DIFFERENCE  NUM_JOBS  GROWTH_PCT  \
# 0         5.465         5.918            0.452    2454.9        -3.5
# 1         5.600         6.036            0.436    2450.9        -6.2
# 2         5.910         6.320            0.410    2442.4        -6.1
# 3         5.972         6.426            0.454    2434.6        -6.8
# 4         6.025         6.478            0.452    2429.3        -7.2
#
#    People25PlusThousands_2019  PctHighSchoolDiploma_2019  \
# 0                  4414.04779                  89.810682
# 1                  4414.04779                  89.810682
# 2                  4414.04779                  89.810682
# 3                  4414.04779                  89.810682
# 4                  4414.04779                  89.810682
#
#    PctBachelorsDegree_2019     CityName
# 0                41.859123  ATLANTA, GA
# 1                41.859123  ATLANTA, GA
# 2                41.859123  ATLANTA, GA
# 3                41.859123  ATLANTA, GA
# 4                41.859123  ATLANTA, GA
#
# [5 rows x 25 columns]

# %%
# Make predictions with HistGradientBoost
#reg.best_model = model_dict['Linear Regression']
lr_predictions = reg.predict(test_full_df)
lr_predictions
# Out:
# array([243271.10386831, 243271.10386831, 248650.23004964, ...,
#        644800.46684432, 644800.46684432, 644800.46684432])

# %%
# Plot Actual vs Predictions
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("All Cities Predictions vs Actuals")
ax.plot(
    lr_predictions,
    "x-",
    alpha=0.2,
    label=f"Actual {target_col} values",
    color="black",
)
ax.plot(lr_predictions, "x-", label="HistGradientBoost")
_ = ax.legend()

""" lr_predictions here is clearly not right, not sure where I can grab the actuals given the parameters of the pipeline"""
# Out:
# ' lr_predictions here is clearly not right, not sure where I can grab the actuals given the parameters of the pipeline'
