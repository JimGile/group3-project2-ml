# %%
state_zvhi = pd.read_csv('/Users/timwillard/Desktop/group3-project2-ml/tw/Zillow/State_zhvi.csv') 
print(state_zvhi.head())
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName     2000-01-31  \
# 0         9         0    California      state        NaN  191545.840185
# 1        54         1         Texas      state        NaN  112965.763960
# 2        14         2       Florida      state        NaN  107876.988002
# 3        43         3      New York      state        NaN  155482.537043
# 4        47         4  Pennsylvania      state        NaN   99875.274333
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  192189.682926  193059.028286  194946.117850  197139.575194  ...
# 1  113027.152474  113056.926865  113204.699809  113300.399884  ...
# 2  108110.659600  108393.916155  108969.703876  109590.628885  ...
# 3  156036.207607  156569.204812  157715.536908  158901.580849  ...
# 4  100088.899981  100289.650707  100698.750181  101118.997774  ...
#
#       2023-10-31     2023-11-30     2023-12-31     2024-01-31     2024-02-29  \
# ...

# %%
state_zvhi.set_index('RegionName', inplace=True)

# %%
state_zvhi = state_zvhi.drop(columns=['RegionID', 'SizeRank', 'RegionType', 'StateName'])
print(state_zvhi.head())
# Out:
#                  2000-01-31     2000-02-29     2000-03-31     2000-04-30  \
# RegionName
# California    191545.840185  192189.682926  193059.028286  194946.117850
# Texas         112965.763960  113027.152474  113056.926865  113204.699809
# Florida       107876.988002  108110.659600  108393.916155  108969.703876
# New York      155482.537043  156036.207607  156569.204812  157715.536908
# Pennsylvania   99875.274333  100088.899981  100289.650707  100698.750181
#
#                  2000-05-31     2000-06-30     2000-07-31     2000-08-31  \
# RegionName
# California    197139.575194  199506.309297  202005.749556  204615.297172
# Texas         113300.399884  113407.702966  113478.217693  113686.827964
# Florida       109590.628885  110224.172449  110860.728771  111509.028745
# New York      158901.580849  160184.022348  161336.932702  162346.109844
# Pennsylvania  101118.997774  101550.898609  102009.550658  102447.383700
#
# ...

# %%
state_zvhi_transposed = state_zvhi.transpose()

# %%
state_zvhi_transposed.index = pd.to_datetime(state_zvhi_transposed.index)
state_zvhi_transposed.head()
# Out:
# RegionName     California          Texas        Florida       New York  \
# 2000-01-31  191545.840185  112965.763960  107876.988002  155482.537043
# 2000-02-29  192189.682926  113027.152474  108110.659600  156036.207607
# 2000-03-31  193059.028286  113056.926865  108393.916155  156569.204812
# 2000-04-30  194946.117850  113204.699809  108969.703876  157715.536908
# 2000-05-31  197139.575194  113300.399884  109590.628885  158901.580849
#
# RegionName   Pennsylvania       Illinois           Ohio        Georgia  \
# 2000-01-31   99875.274333  129963.014485  107657.549547  124863.139050
# 2000-02-29  100088.899981  130067.167750  107723.338075  125146.681646
# 2000-03-31  100289.650707  130292.299706  107823.109867  125473.842450
# 2000-04-30  100698.750181  130821.919660  108116.493633  126162.659546
# 2000-05-31  101118.997774  131450.330292  108563.830920  126922.397367
#
# RegionName  North Carolina       Michigan  ...          Maine   Rhode Island  \
# ...

# %%
state_zvhi_transposed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 295 entries, 2000-01-31 to 2024-07-31
# Data columns (total 51 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   California            295 non-null    float64
#  1   Texas                 295 non-null    float64
#  2   Florida               295 non-null    float64
#  3   New York              295 non-null    float64
#  4   Pennsylvania          295 non-null    float64
#  5   Illinois              295 non-null    float64
#  6   Ohio                  295 non-null    float64
#  7   Georgia               295 non-null    float64
#  8   North Carolina        295 non-null    float64
#  9   Michigan              295 non-null    float64
#  10  New Jersey            295 non-null    float64
#  11  Virginia              295 non-null    float64
#  12  Washington            295 non-null    float64
#  13  Arizona               294 non-null    float64
# ...

# %%
# Interpolate missing values using linear interpolation
state_zvhi_transposed_interpolated = state_zvhi_transposed.interpolate(method='linear')

# %%
# Round all numbers to 0 decimal places
state_zvhi_transposed_interpolated_rounded = state_zvhi_transposed_interpolated.round(0)

# %%
state_zvhi_transposed_interpolated_rounded.head()
# Out:
# RegionName  California     Texas   Florida  New York  Pennsylvania  Illinois  \
# 2000-01-31    191546.0  112966.0  107877.0  155483.0       99875.0  129963.0
# 2000-02-29    192190.0  113027.0  108111.0  156036.0      100089.0  130067.0
# 2000-03-31    193059.0  113057.0  108394.0  156569.0      100290.0  130292.0
# 2000-04-30    194946.0  113205.0  108970.0  157716.0      100699.0  130822.0
# 2000-05-31    197140.0  113300.0  109591.0  158902.0      101119.0  131450.0
#
# RegionName      Ohio   Georgia  North Carolina  Michigan  ...     Maine  \
# 2000-01-31  107658.0  124863.0        129865.0  118818.0  ...  109583.0
# 2000-02-29  107723.0  125147.0        130062.0  118883.0  ...  109947.0
# 2000-03-31  107823.0  125474.0        130266.0  119123.0  ...  110273.0
# 2000-04-30  108116.0  126163.0        130707.0  119600.0  ...  110990.0
# 2000-05-31  108564.0  126922.0        131199.0  120304.0  ...  111666.0
#
# ...
